# %%
import sys
sys.path.append('../src/utils/')
from configure import *
from mod_dataprep import *
#from IPython.display import display, HTML

# %%
print checkexist('AAPL')
print checkexist('APL')
print checkexist('ABEOW')
# Out:
# True
# ERROR: APL does not exsit!
# False
# ERROR: data of ABEOW does not exist!
# False

# %%
getfullinfo('AAPL')
# Out:
#   Exchange Symbol        Name  Exist LastSale MarketCap IPOyear      Sector  \
# 0   NASDAQ   AAPL  Apple Inc.      1   164.34  $833.86B    1980  Technology
#
#                  industry  Start_date    End_date
# 0  Computer Manufacturing  1980-12-12  2018-02-16

# %%
getfullinfo('APL')
# Out:
# ERROR: APL does not exsit!

# %%
getfullinfo('ABEOW')
# Out:
#   Exchange Symbol                      Name  Exist LastSale MarketCap IPOyear  \
# 0   NASDAQ  ABEOW  Abeona Therapeutics Inc.      0      7.2       n/a     n/a
#
#         Sector               industry Start_date End_date
# 0  Health Care  Major Pharmaceuticals        ---      ---

# %%
getonequote('AAPL')
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.513393    0.515625    0.513393    0.513393    0.023357
# 1     1980-12-15    0.488839    0.488839    0.486607    0.486607    0.022139
# 2     1980-12-16    0.453125    0.453125    0.450893    0.450893    0.020514
# 3     1980-12-17    0.462054    0.464286    0.462054    0.462054    0.021022
# 4     1980-12-18    0.475446    0.477679    0.475446    0.475446    0.021631
# 5     1980-12-19    0.504464    0.506696    0.504464    0.504464    0.022951
# 6     1980-12-22    0.529018    0.531250    0.529018    0.529018    0.024068
# 7     1980-12-23    0.551339    0.553571    0.551339    0.551339    0.025084
# 8     1980-12-24    0.580357    0.582589    0.580357    0.580357    0.026404
# 9     1980-12-26    0.633929    0.636161    0.633929    0.633929    0.028841
# 10    1980-12-29    0.642857    0.645089    0.642857    0.642857    0.029248
# ...

# %%
getonequote('APL')
# Out:
# ERROR: APL does not exsit!

# %%
getonequote('ABEOW')
# Out:
# ERROR: data of ABEOW does not exist!

# %%
quote = getonequote('GOOG')
quote[3362:3378]
# Out:
#             Date         Open         High          Low        Close  \
# 3362  2017-12-26  1058.069946  1060.119995  1050.199951  1056.739990
# 3363  2017-12-27  1057.390015  1058.369995  1048.050049  1049.369995
# 3364  2017-12-28  1051.599976  1054.750000  1044.770020  1048.140015
# 3365  2017-12-29  1046.719971  1049.699951  1044.900024  1046.400024
# 3366  2018-01-01         null         null         null         null
# 3367  2018-01-02  1048.339966  1066.939941  1045.229980  1065.000000
# 3368  2018-01-03  1064.310059  1086.290039  1063.209961  1082.479980
# 3369  2018-01-04  1088.000000  1093.569946  1084.001953  1086.400024
# 3370  2018-01-05  1094.000000  1104.250000  1092.000000  1102.229980
# 3371  2018-01-08  1102.229980  1111.270020  1101.619995  1106.939941
# 3372  2018-01-09  1109.400024  1110.569946  1101.230957  1106.260010
# 3373  2018-01-10  1097.099976  1104.599976  1096.109985  1102.609985
# 3374  2018-01-11  1106.300049  1106.525024  1099.589966  1105.520020
# ...

# %%
quote = clean_null(quote)
quote[3362:3378]
# Out:
#             Date         Open         High          Low        Close  \
# 3362  2017-12-26  1058.069946  1060.119995  1050.199951  1056.739990
# 3363  2017-12-27  1057.390015  1058.369995  1048.050049  1049.369995
# 3364  2017-12-28  1051.599976  1054.750000  1044.770020  1048.140015
# 3365  2017-12-29  1046.719971  1049.699951  1044.900024  1046.400024
# 3367  2018-01-02  1048.339966  1066.939941  1045.229980  1065.000000
# 3368  2018-01-03  1064.310059  1086.290039  1063.209961  1082.479980
# 3369  2018-01-04  1088.000000  1093.569946  1084.001953  1086.400024
# 3370  2018-01-05  1094.000000  1104.250000  1092.000000  1102.229980
# 3371  2018-01-08  1102.229980  1111.270020  1101.619995  1106.939941
# 3372  2018-01-09  1109.400024  1110.569946  1101.230957  1106.260010
# 3373  2018-01-10  1097.099976  1104.599976  1096.109985  1102.609985
# 3374  2018-01-11  1106.300049  1106.525024  1099.589966  1105.520020
# 3375  2018-01-12  1102.410034  1124.290039  1101.150024  1122.260010
# ...

# %%
quote = add_datetime(quote)
quote[3365:3370]
# Out:
#             Date         Open         High          Low        Close  \
# 3365  2017-12-29  1046.719971  1049.699951  1044.900024  1046.400024
# 3367  2018-01-02  1048.339966  1066.939941  1045.229980  1065.000000
# 3368  2018-01-03  1064.310059  1086.290039  1063.209961  1082.479980
# 3369  2018-01-04  1088.000000  1093.569946  1084.001953  1086.400024
# 3370  2018-01-05  1094.000000  1104.250000  1092.000000  1102.229980
#
#         Adj Close   Volume   datetime
# 3365  1046.400024   887500 2017-12-29
# 3367  1065.000000  1237600 2018-01-02
# 3368  1082.479980  1430200 2018-01-03
# 3369  1086.400024  1004600 2018-01-04
# 3370  1102.229980  1279100 2018-01-05

# %%
quote = getonequote('GOOG')
quote = add_logreturn(quote)
quote[3363:3368]
# Out:
# cleanning null data ...
# null data:  2
# valid data:  3400
#             Date         Open         High          Low        Close  \
# 3363  2017-12-27  1057.390015  1058.369995  1048.050049  1049.369995
# 3364  2017-12-28  1051.599976  1054.750000  1044.770020  1048.140015
# 3365  2017-12-29  1046.719971  1049.699951  1044.900024  1046.400024
# 3367  2018-01-02  1048.339966  1066.939941  1045.229980  1065.000000
# 3368  2018-01-03  1064.310059  1086.290039  1063.209961  1082.479980
#
#         Adj Close   Volume  logreturn_0  logreturn_1
# 3363  1049.369995  1271900    -0.007614    -0.006999
# 3364  1048.140015   837100    -0.003296    -0.001173
# 3365  1046.400024   887500    -0.000306    -0.001661
# 3367  1065.000000  1237600     0.015767     0.017619
# 3368  1082.479980  1430200     0.016928     0.016280

# %%
getinfo_mulquote(['APL','AAPL', 'MS'])
# Out:
# ERROR: APL does not exsit!
#   Exchange Symbol            Name  Exist LastSale MarketCap IPOyear  \
# 0   NASDAQ   AAPL      Apple Inc.      1   164.34  $833.86B    1980
# 0     NYSE     MS  Morgan Stanley      1    53.39   $95.46B     n/a
#
#        Sector                            industry  Start_date    End_date
# 0  Technology              Computer Manufacturing  1980-12-12  2018-02-16
# 0     Finance  Investment Bankers/Brokers/Service  1993-02-23  2018-02-16
