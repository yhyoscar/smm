# %% [markdown]
# # Some general explorations of US stock market
#
# *Haiyang Yu, 02/28/2018*

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 14})

import sys
sys.path.append('../src/utils/')
from configure import *
from mod_dataprep import *

# %%
fslist
# Out:
# 'http://129.49.67.246/stock/histdata/daily//stocks_list.csv'

# %%
ss = pd.read_csv(fslist)
print(format(len(ss)))
ss.head(5)
# Out:
# 6791
#   Exchange Symbol                           Name  Exist  LastSale MarketCap  \
# 0   NASDAQ   AABA                    Altaba Inc.      1     71.31   $62.28B
# 1   NASDAQ    AAL  American Airlines Group, Inc.      1     50.87   $24.34B
# 2   NASDAQ   AAME  Atlantic American Corporation      1      3.25   $66.43M
# 3   NASDAQ   AAOI  Applied Optoelectronics, Inc.      1     29.51  $571.97M
# 4   NASDAQ   AAON                     AAON, Inc.      1     33.90    $1.78B
#
#    IPOyear          Sector                         industry  Start_date  \
# 0      NaN      Technology                     EDP Services  1996-04-12
# 1      NaN  Transportation    Air Freight/Delivery Services  2005-09-27
# 2      NaN         Finance                   Life Insurance  1980-03-17
# 3   2013.0      Technology                   Semiconductors  2013-09-26
# 4      NaN   Capital Goods  Industrial Machinery/Components  1992-12-16
#
#      End_date
# 0  2018-02-16
# 1  2018-02-16
# 2  2018-02-16
# 3  2018-02-16
# 4  2018-02-16

# %%
capnum = [capstr2num(x) for x in ss['MarketCap'].values ]
ss['MarketCap'] = capnum
ss[10:16]
# Out:
#    Exchange Symbol                          Name  Exist  LastSale  \
# 10   NASDAQ   ABAX                  ABAXIS, Inc.      1    65.510
# 11   NASDAQ   ABCB                Ameris Bancorp      1    52.600
# 12   NASDAQ   ABCD  Cambium Learning Group, Inc.      1     7.190
# 13   NASDAQ   ABDC        Alcentra Capital Corp.      1     7.585
# 14   NASDAQ   ABEO      Abeona Therapeutics Inc.      1    11.900
# 15   NASDAQ  ABEOW      Abeona Therapeutics Inc.      0     7.200
#
#        MarketCap  IPOyear             Sector                         industry  \
# 10  1.490000e+09   1992.0      Capital Goods  Industrial Machinery/Components
# 11  1.970000e+09   1994.0            Finance                      Major Banks
# 12  3.355600e+08      NaN  Consumer Services                       Publishing
# 13  1.080500e+08      NaN                NaN                              NaN
# 14  5.566300e+08      NaN        Health Care            Major Pharmaceuticals
# 15           NaN      NaN        Health Care            Major Pharmaceuticals
#
#     Start_date    End_date
# 10  1992-01-23  2018-02-16
# 11  1994-05-19  2018-02-16
# 12  2009-12-09  2018-02-16
# 13  2014-05-09  2018-02-16
# 14  1980-09-19  2018-02-16
# 15         ---         ---

# %%
ss.groupby('Exchange').sum()[  ['Exist', 'MarketCap'] ]
# Out:
#           Exist     MarketCap
# Exchange
# AMEX        311  1.243298e+11
# NASDAQ     3179  1.324625e+13
# NYSE       2624  2.882822e+13

# %%
x = ss.groupby(['Sector'] ).sum()[  ['Exist', 'MarketCap'] ]
x
# Out:
#                        Exist     MarketCap
# Sector
# Basic Industries         317  2.114924e+12
# Capital Goods            374  2.696630e+12
# Consumer Durables        139  4.221904e+11
# Consumer Non-Durables    231  2.461541e+12
# Consumer Services        815  5.644795e+12
# Energy                   314  3.011629e+12
# Finance                  964  6.609852e+12
# Health Care              792  4.911471e+12
# Miscellaneous            145  1.694822e+12
# Public Utilities         282  2.962618e+12
# Technology               616  8.029235e+12
# Transportation           122  8.269322e+11

# %%
plt.figure(1, figsize=(12, 6))
for i in range(len(x.columns)):
    plt.subplot(1,2,i+1)
    plt.barh( range(len(x)), x[x.columns[i]].values)
    plt.yticks(range(len(x)), x.index.values)
    plt.title(x.columns[i])

plt.tight_layout()
plt.show()

print(x.columns[:])
# Out:
# Index(['Exist', 'MarketCap'], dtype='object')

# %%
x0 = ss.groupby(['Exchange','Sector'] ).sum()[  ['Exist', 'MarketCap'] ]
x0
# Out:
#                                 Exist     MarketCap
# Exchange Sector
# AMEX     Basic Industries          47  1.576230e+10
#          Capital Goods             20  1.411580e+09
#          Consumer Durables          4  1.037290e+09
#          Consumer Non-Durables     14  1.085460e+09
#          Consumer Services         31  4.805780e+09
#          Energy                    30  3.104964e+10
#          Finance                   14  9.699550e+09
#          Health Care               45  4.100748e+09
#          Miscellaneous              5  4.191700e+08
#          Public Utilities          10  3.756446e+10
#          Technology                19  1.089280e+09
#          Transportation             1  1.781200e+08
# NASDAQ   Basic Industries          75  6.747245e+10
#          Capital Goods            171  3.089218e+11
#          Consumer Durables         77  7.015999e+10
#          Consumer Non-Durables    110  4.688188e+11
#          Consumer Services        345  2.380882e+12
#          Energy                    63  5.829792e+10
#          Finance                  612  8.389700e+11
#          Health Care              644  1.584755e+12
#          Miscellaneous             90  3.976825e+11
#          Public Utilities          65  3.032724e+11
#          Technology               434  6.126930e+12
#          Transportation            53  1.950675e+11
# NYSE     Basic Industries         195  2.031690e+12
#          Capital Goods            183  2.386297e+12
#          Consumer Durables         58  3.509931e+11
#          Consumer Non-Durables    107  1.991637e+12
#          Consumer Services        439  3.259107e+12
#          Energy                   221  2.922281e+12
#          Finance                  338  5.761183e+12
#          Health Care              103  3.322614e+12
#          Miscellaneous             50  1.296720e+12
#          Public Utilities         207  2.621781e+12
#          Technology               163  1.901215e+12
#          Transportation            68  6.316866e+11

# %%
plt.figure(1, figsize=(12, 6))
for k in range( len(x0.index.levels[0].values) ):
    e = x0.index.levels[0].values[k]
    x = x0.loc[e]
    for i in range(len(x.columns)):
        plt.subplot(1,2,i+1)
        plt.barh( np.arange(len(x))+k*0.25, x[x.columns[i]].values, height=0.25)

        if k==2:
            plt.yticks(np.arange(len(x))+0.25, x.index.values)
            plt.title(x.columns[i])
            plt.legend(x0.index.levels[0].values, loc='best')
            
plt.tight_layout()
plt.show()
# Out:
# /home/oscar/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
x = ss.groupby('IPOyear').sum()[ ['Exist', 'MarketCap'] ]
x
# Out:
#          Exist     MarketCap
# IPOyear
# 1972.0       4  5.600379e+10
# 1973.0       1  1.680000e+09
# 1980.0       2  8.501800e+11
# 1981.0       5  1.619762e+10
# 1982.0       4  3.121320e+09
# 1983.0      11  1.760993e+11
# 1984.0       4  3.355009e+10
# 1985.0       3  3.900841e+10
# 1986.0      37  1.125805e+12
# 1987.0      28  1.844954e+11
# 1988.0      18  7.371378e+10
# 1989.0      17  4.781872e+10
# 1990.0      11  2.529292e+11
# 1991.0      37  2.529240e+11
# 1992.0      68  3.378534e+11
# 1993.0      82  2.736221e+11
# 1994.0      50  2.592404e+11
# 1995.0      36  2.745520e+11
# 1996.0      56  1.748971e+11
# 1997.0      67  1.243218e+12
# 1998.0      44  2.051241e+11
# 1999.0      68  6.536678e+11
# 2000.0      44  2.411078e+11
# 2001.0      30  3.303371e+11
# 2002.0      74  3.763509e+11
# 2003.0      61  1.787045e+11
# 2004.0      99  1.134483e+12
# 2005.0      80  2.421827e+11
# 2006.0      84  3.627450e+11
# 2007.0      97  3.078656e+11
# 2008.0      12  4.094917e+10
# 2009.0      43  2.819522e+11
# 2010.0      92  3.087018e+11
# 2011.0     107  2.741599e+11
# 2012.0     114  9.875906e+11
# 2013.0     201  6.344658e+11
# 2014.0     301  1.142175e+12
# 2015.0     249  5.091738e+11
# 2016.0     200  6.052147e+11
# 2017.0     311  5.168287e+11
# 2018.0      39  7.854212e+10

# %%
plt.figure(1, figsize=(14, 8))
for i in range(len(x.columns)):
    plt.subplot(2,1,i+1)
    plt.bar( x.index.values, x[x.columns[i]].values)
    #plt.yticks(range(len(x)), x.index.values)
    plt.title(x.columns[i])

plt.tight_layout()
plt.show()

# %%
ss = ss.replace(to_replace='---', value=np.nan)
ss['Start_date'] = pd.to_datetime(ss['Start_date'])
ss['End_date'] = pd.to_datetime(ss['End_date'])
ss[11:17]
# Out:
#    Exchange Symbol                          Name  Exist  LastSale  \
# 11   NASDAQ   ABCB                Ameris Bancorp      1    52.600
# 12   NASDAQ   ABCD  Cambium Learning Group, Inc.      1     7.190
# 13   NASDAQ   ABDC        Alcentra Capital Corp.      1     7.585
# 14   NASDAQ   ABEO      Abeona Therapeutics Inc.      1    11.900
# 15   NASDAQ  ABEOW      Abeona Therapeutics Inc.      0     7.200
# 16   NASDAQ   ABIL                  Ability Inc.      1     0.381
#
#        MarketCap  IPOyear             Sector               industry  \
# 11  1.970000e+09   1994.0            Finance            Major Banks
# 12  3.355600e+08      NaN  Consumer Services             Publishing
# 13  1.080500e+08      NaN                NaN                    NaN
# 14  5.566300e+08      NaN        Health Care  Major Pharmaceuticals
# 15           NaN      NaN        Health Care  Major Pharmaceuticals
# 16  9.810000e+06   2014.0            Finance      Business Services
#
#    Start_date   End_date
# 11 1994-05-19 2018-02-16
# 12 2009-12-09 2018-02-16
# 13 2014-05-09 2018-02-16
# 14 1980-09-19 2018-02-16
# 15        NaT        NaT
# 16 2014-02-05 2018-02-16

# %%
ss['Start_year'] = ss['Start_date'].dt.to_period('Y')
ss[11:17]
# Out:
#    Exchange Symbol                          Name  Exist  LastSale  \
# 11   NASDAQ   ABCB                Ameris Bancorp      1    52.600
# 12   NASDAQ   ABCD  Cambium Learning Group, Inc.      1     7.190
# 13   NASDAQ   ABDC        Alcentra Capital Corp.      1     7.585
# 14   NASDAQ   ABEO      Abeona Therapeutics Inc.      1    11.900
# 15   NASDAQ  ABEOW      Abeona Therapeutics Inc.      0     7.200
# 16   NASDAQ   ABIL                  Ability Inc.      1     0.381
#
#        MarketCap  IPOyear             Sector               industry  \
# 11  1.970000e+09   1994.0            Finance            Major Banks
# 12  3.355600e+08      NaN  Consumer Services             Publishing
# 13  1.080500e+08      NaN                NaN                    NaN
# 14  5.566300e+08      NaN        Health Care  Major Pharmaceuticals
# 15           NaN      NaN        Health Care  Major Pharmaceuticals
# 16  9.810000e+06   2014.0            Finance      Business Services
#
#    Start_date   End_date Start_year
# 11 1994-05-19 2018-02-16       1994
# 12 2009-12-09 2018-02-16       2009
# 13 2014-05-09 2018-02-16       2014
# 14 1980-09-19 2018-02-16       1980
# 15        NaT        NaT        NaT
# 16 2014-02-05 2018-02-16       2014

# %%
x = ss.groupby('Start_year').sum()[ ['Exist', 'MarketCap'] ]
x
# Out:
#             Exist     MarketCap
# Start_year
# 1962            9  9.597600e+11
# 1970           24  1.987643e+12
# 1972           22  1.741620e+12
# 1973           26  3.153224e+11
# 1974            1  5.972000e+10
# 1975            1  2.964000e+07
# 1976            1  1.983900e+11
# 1977           10  6.572432e+11
# 1978            3  6.463497e+10
# 1979            1  1.436000e+10
# 1980          369  6.201095e+12
# 1981           43  1.113984e+12
# 1982           24  2.639542e+11
# 1983           49  8.498394e+11
# 1984           49  6.190719e+11
# 1985           42  4.004035e+11
# 1986           76  1.505027e+12
# 1987          102  6.452660e+11
# 1988           51  4.588906e+11
# 1989           37  3.307929e+11
# 1990           65  4.734842e+11
# 1991           76  7.010354e+11
# 1992          142  5.593416e+11
# 1993          148  8.830466e+11
# 1994          152  8.443121e+11
# 1995          149  9.554240e+11
# 1996          141  9.292546e+11
# 1997          138  1.824028e+12
# 1998          114  6.652048e+11
# 1999          195  1.341845e+12
# 2000          162  1.228132e+12
# 2001           77  1.271568e+12
# 2002          117  8.094800e+11
# 2003          139  4.804884e+11
# 2004          154  1.955559e+12
# 2005          179  5.738357e+11
# 2006          171  6.347731e+11
# 2007          255  7.998104e+11
# 2008          100  6.412429e+11
# 2009           89  5.517008e+11
# 2010          214  6.573370e+11
# 2011          167  3.994706e+11
# 2012          201  9.784934e+11
# 2013          282  7.587240e+11
# 2014          371  1.095973e+12
# 2015          258  5.979375e+11
# 2016          271  6.455334e+11
# 2017          450  4.847178e+11
# 2018          197  6.999725e+10

# %%
plt.figure(1, figsize=(14, 8))
for i in range(len(x.columns)):
    plt.subplot(2,1,i+1)
    plt.bar( x.index.astype(int)+1970, x[x.columns[i]].values)
    #plt.yticks(range(len(x)), x.index.values)
    plt.title(x.columns[i])

plt.tight_layout()
plt.show()

# %%
x0 = ss.groupby(['Exchange','Start_year'] ).sum()[  ['Exist', 'MarketCap'] ]
plt.figure(1, figsize=(14, 8))
for k in range( len(x0.index.levels[0].values) ):
    e = x0.index.levels[0].values[k]
    x = x0.loc[e]
    for i in range(len(x.columns)):
        plt.subplot(2,1,i+1)
        plt.bar( x.index.astype(int)+1970+(k-1)*0.25, x[x.columns[i]].values, width=0.25)
        if k==2:
            plt.title(x.columns[i])
            plt.legend(x0.index.levels[0].values, loc='best')
            
plt.tight_layout()
plt.show()
# Out:
# /home/oscar/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
ss.shape
# Out:
# (6791, 12)

# %%
ss.sort_values('MarketCap', ascending=False).head(10)
# Out:
#      Exchange Symbol                           Name  Exist  LastSale  \
# 5      NASDAQ   AAPL                     Apple Inc.      1    164.34
# 1325   NASDAQ  GOOGL                  Alphabet Inc.      1   1054.14
# 1324   NASDAQ   GOOG                  Alphabet Inc.      1   1052.10
# 1994   NASDAQ   MSFT          Microsoft Corporation      1     89.83
# 176    NASDAQ   AMZN               Amazon.com, Inc.      1   1414.51
# 1059   NASDAQ     FB                 Facebook, Inc.      1    173.15
# 3573     NYSE   BABA  Alibaba Group Holding Limited      1    179.25
# 4861     NYSE    JPM          J P Morgan Chase & Co      1    112.43
# 4853     NYSE    JNJ              Johnson & Johnson      1    129.96
# 6404     NYSE    XOM        Exxon Mobil Corporation      1     76.30
#
#          MarketCap  IPOyear             Sector  \
# 5     8.338600e+11   1980.0         Technology
# 1325  7.329400e+11      NaN         Technology
# 1324  7.315200e+11   2004.0         Technology
# 1994  6.916700e+11   1986.0         Technology
# 176   6.847700e+11   1997.0  Consumer Services
# 1059  5.030000e+11   2012.0         Technology
# 3573  4.599300e+11   2014.0      Miscellaneous
# 4861  3.851100e+11      NaN            Finance
# 4853  3.491400e+11      NaN        Health Care
# 6404  3.234400e+11      NaN             Energy
#
#                                              industry Start_date   End_date  \
# 5                              Computer Manufacturing 1980-12-12 2018-02-16
# 1325  Computer Software: Programming, Data Processing 2004-08-19 2018-02-16
# 1324  Computer Software: Programming, Data Processing 2004-08-19 2018-02-16
# 1994          Computer Software: Prepackaged Software 1986-03-13 2018-02-16
# 176                    Catalog/Specialty Distribution 1997-05-15 2018-02-16
# 1059  Computer Software: Programming, Data Processing 2012-05-18 2018-02-16
# 3573                                Business Services 2014-09-19 2018-02-16
# 4861                                      Major Banks 1980-03-17 2018-02-16
# 4853                            Major Pharmaceuticals 1970-01-02 2018-02-16
# 6404                         Integrated oil Companies 1970-01-02 2018-02-16
#
#      Start_year
# 5          1980
# 1325       2004
# 1324       2004
# 1994       1986
# 176        1997
# 1059       2012
# 3573       2014
# 4861       1980
# 4853       1970
# 6404       1970

# %%
ntop = 20
tops = ss.sort_values('MarketCap', ascending=False).head(ntop)['Name']
topp = ss.sort_values('MarketCap', ascending=False).head(ntop)['MarketCap']
topp = np.cumsum(topp)/ss['MarketCap'].sum()

plt.figure(1, figsize=(5,10))
plt.barh(range(ntop), topp)
plt.yticks(range(ntop), tops, fontsize=14)
plt.show()
